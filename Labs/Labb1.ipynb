# %% [markdown]
# ## Laboration – Covid-19
# #The Covid-19 pandemic has affected the entire world with many deaths as a result.
#
# #A powerful tool for understanding how the virus affects the world is to analyze and visualize data to understand trends.分析和可视化数据以了解趋势

# %% [markdown]
# # Number of death per day

# %%
import pandas as pd

death = pd.read_excel("../datasource/Folkhalsomyndigheten_Covid19.xlsx", sheet_name=1)
death.head()
# Out:
#          Datum_avliden  Antal_avlidna
# 0  2020-03-11 00:00:00              1
# 1  2020-03-12 00:00:00              0
# 2  2020-03-13 00:00:00              1
# 3  2020-03-14 00:00:00              1
# 4  2020-03-15 00:00:00              2

# %%
death.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 591 entries, 0 to 590
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Datum_avliden  0 non-null      float64
#  1   Antal_avlidna  591 non-null    int64
# dtypes: float64(1), int64(1)
# memory usage: 9.4 KB

# %%
death["Datum_avliden"]=death["Datum_avliden"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19340/1279376504.py in <module>
# ----> 1 death["Datum_avliden"]=death["Datum_avliden"].astype(int)
#
# ~\.virtualenvs\Databehandling_Xiu-TYvkZc4P\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\.virtualenvs\Databehandling_Xiu-TYvkZc4P\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...

# %%
# convert Calories to int type
#death["Datum_avliden"]=death["Datum_avliden"].str[:10]

from datetime import datetime, timezone
import time
death=datetime.strptime(st[:10])
#df["Calories"] = df["Calories"].str[:10] #把列Calories 62cal改成62，去掉后面的三个字节
#df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19340/1692507364.py in <module>
#       4 from datetime import datetime, timezone
#       5 import time
# ----> 6 death=datetime.strptime(st[:10])
#       7 #df["Calories"] = df["Calories"].str[:10] #把列Calories 62cal改成62，去掉后面的三个字节
#       8 #df.head()
#
# NameError: name 'st' is not defined

# %%
df.sum()
# Out:
# C:\Users\Xiu\AppData\Local\Temp/ipykernel_19340/1703867807.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.sum()
# Antal_avlidna    14993
# dtype: int64

# %% [markdown]
# # Line chart

# %%
import plotly_express as px 
import matplotlib.pyplot as plt
fig=px.line(death,x="Datum_avliden",y="Antal_avlidna",title="Covid death per day",log_x=True,range_x=[1900,2020])
fig.show()

# %% [markdown]
# # Number of intensive care per day

# %%
df = pd.read_excel("../datasource/Folkhalsomyndigheten_Covid19.xlsx",sheet_name=2)
df.head()
# Out:
#   Datum_vårdstart  Antal_intensivvårdade
# 0      2020-03-06                      1
# 1      2020-03-07                      1
# 2      2020-03-08                      1
# 3      2020-03-09                      0
# 4      2020-03-10                      2
