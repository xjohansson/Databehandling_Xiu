# %% [markdown]
# # L0 Pandas basics exerience

# %% [markdown]
# # 1. Cities in Sweden - create dataset (*)

# %% [markdown]
#  # a) Use your DataFrame to print out all the cities. (*)

# %%
import pandas as pd
data=dict(Malmö=347949, Stockholm=975551, Uppsala=233839, Göteborg=583056) #poulation of the city
series_population=pd.Series(data=data)
print(series_population)

# extract values
print(f"series_populations[1]: {series_population[1]}")
#get the keys
print(f"series_populations.keys() : {series_population.keys()}")
print(f"series_populations.keys() [3]: {series_population[1]}")
# Out:
# Malmö        347949
# Stockholm    975551
# Uppsala      233839
# Göteborg     583056
# dtype: int64
# series_populations[1]: 975551
# series_populations.keys() : Index(['Malmö', 'Stockholm', 'Uppsala', 'Göteborg'], dtype='object')
# series_populations.keys() [3]: 975551

# %%
#df=pd.DataFrame(series_population,columns=("Kommun,Population",))
df=pd.DataFrame(series_population)
df
#df[["Kommun","Population"]] #select two columns
# 括号里面如果没有逗号，会出现以下错误提示
# TypeError: Index(...) must be called with a collection of some kind, 'Num of population' was passed
# Out:
#                 0
# Malmö      347949
# Stockholm  975551
# Uppsala    233839
# Göteborg   583056

# %%
import pandas as pd
data={
    "kommun":["Malmö","Stockholm","Uppsala","Göteborg"],
    "population":[347949,975551,233839,583056]
}

#load data into a DataFrame object:
df = pd.DataFrame(data)

print(df)
# Out:
#       kommun  population
# 0      Malmö      347949
# 1  Stockholm      975551
# 2    Uppsala      233839
# 3   Göteborg      583056

# %%
print(df.loc[3]) #return row 3
#use a list of indexes:
print(df.loc[[0,1]]) # Return row 0 and 1:
# Out:
# kommun        Göteborg
# population      583056
# Name: 3, dtype: object
#       kommun  population
# 0      Malmö      347949
# 1  Stockholm      975551

# %% [markdown]
# # b) Select only the row which contains Göteborg. Do this by using the name Göteborg. (*)

# %%
#return row 3:返回到第四行
print(df.loc[3])
# Out:
# kommun        Göteborg
# population      583056
# Name: 3, dtype: object

# %% [markdown]
# # c) Sort the cities by population from largest to smallest.

# %%
df1=df.sort_values(by="population",ascending=False) # 按人口的降序排列sorting descending by population column
df1
# Out:
#       kommun  population
# 1  Stockholm      975551
# 3   Göteborg      583056
# 0      Malmö      347949
# 2    Uppsala      233839

# %% [markdown]
# # d) Filter out the three largest cities. (*)

# %%
top3= df1.iloc[:3].reset_index()
top3
# Out:
#    index     kommun  population
# 0      1  Stockholm      975551
# 1      3   Göteborg      583056
# 2      0      Malmö      347949

# %% [markdown]
# # e) The whole population in Sweden 2020 is 10379295. Use this number to create a new column in your sorted DataFrame named: Population (%).
#  # This column should be filled with percentage of the Swedish population for each city.

# %% [markdown]
# # 2. Cities in Sweden - real dataset (*)

# %%
import pandas as pd 

df = pd.read_excel("./komtopp50_2020.xlsx",sheet_name=1)
df.head(50) 

df = df.rename(dict(Cals_per100grams="Calories",
               per100grams="per100", KJ_per100grams="kJ"), axis="columns") #简化三列的名称，重新命名
df.head()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10536/759210622.py in <module>
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_excel("./komtopp50_2020.xlsx",sheet_name=1)
#       4 df.head(50)
#       5
#
# ~\.virtualenvs\Databehandling-21-H5KdRmYh\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df.describe()
# Out:
#         Unnamed: 1     Unnamed: 4
# count   291.000000     291.000000
# mean    151.934708   35496.934708
# std     138.092769   74190.464321
# min       1.000000    2019.000000
# 25%      73.500000   10005.000000
# 50%     146.000000   15940.000000
# 75%     218.500000   35649.500000
# max    2019.000000  974073.000000

# %%
# Drop rows 删除行 方法二
df1=df.drop(index=[0, 1,2,3,4,5]) #删除前六行
df1
# Out:
#     Unnamed: 0  Unnamed: 1    Unnamed: 2 Unnamed: 3  Unnamed: 4 Unnamed: 5
# 6           83        84.0           Ale      31868     31402.0   1.483982
# 7           64        64.0      Alingsås      41602     41420.0   0.439401
# 8          123       123.0       Alvesta      20224     20134.0   0.447005
# 9          255       255.0         Aneby       6821      6848.0  -0.394276
# 10         169       167.0        Arboga      14039     14087.0   -0.34074
# ..         ...         ...           ...        ...         ...        ...
# 291         54        55.0     Österåker      46644     45574.0    2.34783
# 292        116       115.0     Östhammar      22251     22250.0   0.004494
# 293        160       159.0  Östra Göinge      15017     15007.0   0.066636
# 294        284       284.0     Överkalix       3289      3315.0  -0.784314
# 295        279       279.0    Övertorneå       4217      4299.0   -1.90742
#
# [290 rows x 6 columns]

# %%
# data.rename(columns={'oldname':'newname'}, inplace=True), 重新给无列名的列赋予名字
df1.rename(columns = {"Unnamed: 0" : "Rang2020","Unnamed: 1" : "Rang2019","Unnamed: 2" :"Kommun","Unnamed: 3" : "Folkmängd 2020","Unnamed: 4" : "Folkmängd 2019","Unnamed: 5" : "Förändring"}, inplace = True)
df1
# Out:
#     Rang2020  Rang2019        Kommun Folkmängd 2020  Folkmängd 2019 Förändring
# 6         83      84.0           Ale          31868         31402.0   1.483982
# 7         64      64.0      Alingsås          41602         41420.0   0.439401
# 8        123     123.0       Alvesta          20224         20134.0   0.447005
# 9        255     255.0         Aneby           6821          6848.0  -0.394276
# 10       169     167.0        Arboga          14039         14087.0   -0.34074
# ..       ...       ...           ...            ...             ...        ...
# 291       54      55.0     Österåker          46644         45574.0    2.34783
# 292      116     115.0     Östhammar          22251         22250.0   0.004494
# 293      160     159.0  Östra Göinge          15017         15007.0   0.066636
# 294      284     284.0     Överkalix           3289          3315.0  -0.784314
# 295      279     279.0    Övertorneå           4217          4299.0   -1.90742
#
# [290 rows x 6 columns]

# %%
# data.rename(columns={'oldname':'newname'}, inplace=True), 0 是列名1，2是列名3
df1.rename(columns = {"0" : "Rang2020"," 1" : "Rang2019","2" :"Kommun","3" : "Folkmängd 2020"," 4" : "Folkmängd 2019"," 5" : "Förändring"}, inplace = True)
df1
# Out:
#     Rang2020  Rang2019        Kommun Folkmängd 2020  Folkmängd 2019 Förändring
# 6         83      84.0           Ale          31868         31402.0   1.483982
# 7         64      64.0      Alingsås          41602         41420.0   0.439401
# 8        123     123.0       Alvesta          20224         20134.0   0.447005
# 9        255     255.0         Aneby           6821          6848.0  -0.394276
# 10       169     167.0        Arboga          14039         14087.0   -0.34074
# ..       ...       ...           ...            ...             ...        ...
# 291       54      55.0     Österåker          46644         45574.0    2.34783
# 292      116     115.0     Östhammar          22251         22250.0   0.004494
# 293      160     159.0  Östra Göinge          15017         15007.0   0.066636
# 294      284     284.0     Överkalix           3289          3315.0  -0.784314
# 295      279     279.0    Övertorneå           4217          4299.0   -1.90742
#
# [290 rows x 6 columns]

# %%
df1.reset_index(drop=True)
#drop=True就是把原来的索引index列去掉，重置index。

#drop=False就是保留原来的索引，添加重置的index。

#两者的区别就是有没有把原来的index去掉。
# Out:
#     Rang2020  Rang2019        Kommun Folkmängd 2020  Folkmängd 2019 Förändring
# 0         83      84.0           Ale          31868         31402.0   1.483982
# 1         64      64.0      Alingsås          41602         41420.0   0.439401
# 2        123     123.0       Alvesta          20224         20134.0   0.447005
# 3        255     255.0         Aneby           6821          6848.0  -0.394276
# 4        169     167.0        Arboga          14039         14087.0   -0.34074
# ..       ...       ...           ...            ...             ...        ...
# 285       54      55.0     Österåker          46644         45574.0    2.34783
# 286      116     115.0     Östhammar          22251         22250.0   0.004494
# 287      160     159.0  Östra Göinge          15017         15007.0   0.066636
# 288      284     284.0     Överkalix           3289          3315.0  -0.784314
# 289      279     279.0    Övertorneå           4217          4299.0   -1.90742
#
# [290 rows x 6 columns]

# %% [markdown]
# # c

# %%
# Sort the cities by population from largest to smallest. (*)
#sortlist=df1.sort_values(by="Folkmängd 2020", ascending=False) 

sortlist=df1.groupby.sort_values(by="Folkmängd 2020", ascending=False).reset_index()
sortlist

# top five food categories 前五名食物种类
#top5_median = df.groupby("FoodCategory").median().sort_values(by="Calories", ascending=False).head().reset_index() #从新拍序列号
#top5_median #中位数?????????????
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10536/4290962496.py in <module>
#       2 #sortlist=df1.sort_values(by="Folkmängd 2020", ascending=False)
#       3
# ----> 4 sortlist=df1.groupby.sort_values(by="Folkmängd 2020", ascending=False).reset_index()
#       5 sortlist
#       6
#
# NameError: name 'df1' is not defined

# %%
top5=sortlist.iloc[:5] 
top5
# Out:
#     Rang2020  Rang2019     Kommun Folkmängd 2020  Folkmängd 2019 Förändring
# 204        1       1.0  Stockholm         975551        974073.0   0.151734
# 63         2       2.0   Göteborg         583056        579281.0    0.65167
# 140        3       3.0      Malmö         347949        344166.0   1.099179
# 247        4       4.0    Uppsala         233839        230767.0   1.331213
# 130        5       5.0  Linköping         164616        163051.0   0.959822

# %% [markdown]
# #   d) Filter out the five smallest cities. (*)

# %%
smallest5=sortlist.iloc[-5:] #人口最小的5个城市
smallest5
# Out:
#     Rang2020  Rang2019    Kommun Folkmängd 2020  Folkmängd 2019 Förändring
# 277      286     286.0     Åsele           2805          2794.0   0.393701
# 11       287     287.0  Arjeplog           2718          2785.0  -2.405745
# 35       288     288.0   Dorotea           2498          2551.0  -2.077617
# 200      289     289.0   Sorsele           2442          2489.0  -1.888309
# 18       290     290.0  Bjurholm           2387          2408.0  -0.872093

# %% [markdown]
# #  e) Use the DataFrame to calculate Sweden's population in 2019 and 2020. (*)

# %% [markdown]
# # f) Plot a bar chart for the five largest cities and the five smallest cities. (*)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # 3. Cities in Sweden - gender (*)

# %%
import pandas as pd 

df_woman = pd.read_excel("./komtopp50_2020.xlsx",sheet_name=2)#打开第3个Excel

df_woman.head(20)
# Out:
#                                            Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0                                                 NaN         NaN         NaN
# 1   Antal män per kommun 31 december 2020 jämfört ...         NaN         NaN
# 2   Sorterat i alfabetisk ordning. Rangordning frå...         NaN         NaN
# 3                                                 NaN         NaN         NaN
# 4                                                Rang         NaN      Kommun
# 5                                                2020      2019.0         NaN
# 6                                                  81        83.0         Ale
# 7                                                  64        64.0    Alingsås
# 8                                                 122       123.0     Alvesta
# 9                                                 255       255.0       Aneby
# 10                                                169       168.0      Arboga
# ...

# %%
df2=df_woman .drop(index=[0, 1,2,3,4,5]) #删除前六行
df2
# Out:
#     Unnamed: 0  Unnamed: 1    Unnamed: 2 Unnamed: 3  Unnamed: 4 Unnamed: 5
# 6           84        85.0           Ale      15612     15348.0   1.720094
# 7           64        64.0      Alingsås      20900     20774.0   0.606527
# 8          123       123.0       Alvesta       9857      9795.0   0.632976
# 9          255       255.0         Aneby       3318      3350.0  -0.955224
# 10         165       164.0        Arboga       6945      6973.0  -0.401549
# ..         ...         ...           ...        ...         ...        ...
# 291         55        57.0     Österåker      22997     22442.0   2.473042
# 292        117       118.0     Östhammar      10846     10803.0   0.398038
# 293        160       159.0  Östra Göinge       7270      7262.0   0.110162
# 294        284       284.0     Överkalix       1559      1578.0  -1.204056
# 295        279       279.0    Övertorneå       2027      2065.0  -1.840194
#
# [290 rows x 6 columns]

# %%
# data.rename(columns={'oldname':'newname'}, inplace=True), 重新给无列名的列赋予名字
df2.rename(columns = {"Unnamed: 0" : "Rang2020","Unnamed: 1" : "Rang2019","Unnamed: 2" :"Kommun","Unnamed: 3" : "Folkmängd 2020","Unnamed: 4" : "Folkmängd 2019","Unnamed: 5" : "Förändring"}, inplace = True)
df2
# Out:
#     Rang2020  Rang2019        Kommun Folkmängd 2020  Folkmängd 2019 Förändring
# 6         84      85.0           Ale          15612         15348.0   1.720094
# 7         64      64.0      Alingsås          20900         20774.0   0.606527
# 8        123     123.0       Alvesta           9857          9795.0   0.632976
# 9        255     255.0         Aneby           3318          3350.0  -0.955224
# 10       165     164.0        Arboga           6945          6973.0  -0.401549
# ..       ...       ...           ...            ...             ...        ...
# 291       55      57.0     Österåker          22997         22442.0   2.473042
# 292      117     118.0     Östhammar          10846         10803.0   0.398038
# 293      160     159.0  Östra Göinge           7270          7262.0   0.110162
# 294      284     284.0     Överkalix           1559          1578.0  -1.204056
# 295      279     279.0    Övertorneå           2027          2065.0  -1.840194
#
# [290 rows x 6 columns]

# %%
df2["Kön"]="Kvinna" #增加一列
df2.reset_index(drop=True)
#df2.head()
# Out:
#     Rang2020  Rang2019        Kommun Folkmängd 2020  Folkmängd 2019  \
# 0         84      85.0           Ale          15612         15348.0
# 1         64      64.0      Alingsås          20900         20774.0
# 2        123     123.0       Alvesta           9857          9795.0
# 3        255     255.0         Aneby           3318          3350.0
# 4        165     164.0        Arboga           6945          6973.0
# ..       ...       ...           ...            ...             ...
# 285       55      57.0     Österåker          22997         22442.0
# 286      117     118.0     Östhammar          10846         10803.0
# 287      160     159.0  Östra Göinge           7270          7262.0
# 288      284     284.0     Överkalix           1559          1578.0
# 289      279     279.0    Övertorneå           2027          2065.0
#
#     Förändring     Kön
# 0     1.720094  Kvinna
# 1     0.606527  Kvinna
# 2     0.632976  Kvinna
# 3    -0.955224  Kvinna
# 4    -0.401549  Kvinna
# ...

# %%
df2.head()
# Out:
#    Rang2020  Rang2019    Kommun Folkmängd 2020  Folkmängd 2019 Förändring  \
# 6        84      85.0       Ale          15612         15348.0   1.720094
# 7        64      64.0  Alingsås          20900         20774.0   0.606527
# 8       123     123.0   Alvesta           9857          9795.0   0.632976
# 9       255     255.0     Aneby           3318          3350.0  -0.955224
# 10      165     164.0    Arboga           6945          6973.0  -0.401549
#
#        Kön
# 6   Kvinna
# 7   Kvinna
# 8   Kvinna
# 9   Kvinna
# 10  Kvinna

# %% [markdown]
# # Excel sheet man's data

# %%
df_man = pd.read_excel("./komtopp50_2020.xlsx",sheet_name=3)#打开第4个Excel
df_man.head() 
df3=df_man .drop(index=[0, 1,2,3,4,5]) #删除前六行
df3.rename(columns = {"Unnamed: 0" : "Rang2020","Unnamed: 1" : "Rang2019","Unnamed: 2" :"Kommun","Unnamed: 3" : "Folkmängd 2020","Unnamed: 4" : "Folkmängd 2019","Unnamed: 5" : "Förändring"}, inplace = True)
df4=df3.reset_index(drop=True)
df4["Kön"]="Man" #增加一列man
df4.head()
# Out:
#   Rang2020  Rang2019    Kommun Folkmängd 2020  Folkmängd 2019 Förändring  Kön
# 0       81      83.0       Ale          16256         16054.0   1.258253  Man
# 1       64      64.0  Alingsås          20702         20646.0   0.271239  Man
# 2      122     123.0   Alvesta          10367         10339.0   0.270819  Man
# 3      255     255.0     Aneby           3503          3498.0   0.142939  Man
# 4      169     168.0    Arboga           7094          7114.0  -0.281136  Man

# %%
df4=df3.reset_index(drop=True)
df4
df4.head()
# Out:
#   Rang2020  Rang2019    Kommun Folkmängd 2020  Folkmängd 2019 Förändring  Kön
# 0       81      83.0       Ale          16256         16054.0   1.258253  Man
# 1       64      64.0  Alingsås          20702         20646.0   0.271239  Man
# 2      122     123.0   Alvesta          10367         10339.0   0.270819  Man
# 3      255     255.0     Aneby           3503          3498.0   0.142939  Man
# 4      169     168.0    Arboga           7094          7114.0  -0.281136  Man

# %%
# pandas的DataFrame的append方法详细介
# pandas.DataFrame.append
# DataFrame.append(other, ignore_index=False, verify_integrity=False, sort=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12096/4270797441.py in <module>
# ----> 1 df2=df.assign(Kön=["Kvinna"])
#       2 df2
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in assign(self, **kwargs)
#    4484
#    4485         for k, v in kwargs.items():
# -> 4486             data[k] = com.apply_if_callable(v, data)
#    4487         return data
#    4488
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3610         else:
#    3611             # set column
# -> 3612             self._set_item(key, value)
#    3613
#    3614     def _setitem_slice(self, key: slice, value):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3782         ensure homogeneity.
# ...

# %%
df2.rename(columns = {"0" : "Rang2020"," 1" : "Rang2019","2" :"Kommun","3" : "Folkmängd 2020"," 4" : "Folkmängd 2019"," 5" : "Förändring"}, inplace = True)
df2
# Out:
#     Rang2020  Rang2019        Kommun Folkmängd 2020  Folkmängd 2019 Förändring
# 6         84      85.0           Ale          15612         15348.0   1.720094
# 7         64      64.0      Alingsås          20900         20774.0   0.606527
# 8        123     123.0       Alvesta           9857          9795.0   0.632976
# 9        255     255.0         Aneby           3318          3350.0  -0.955224
# 10       165     164.0        Arboga           6945          6973.0  -0.401549
# ..       ...       ...           ...            ...             ...        ...
# 291       55      57.0     Österåker          22997         22442.0   2.473042
# 292      117     118.0     Östhammar          10846         10803.0   0.398038
# 293      160     159.0  Östra Göinge           7270          7262.0   0.110162
# 294      284     284.0     Överkalix           1559          1578.0  -1.204056
# 295      279     279.0    Övertorneå           2027          2065.0  -1.840194
#
# [290 rows x 6 columns]

# %%
df_woman

# %%
import pandas as pd 
import numpy as np
df = pd.DataFrame(np.arange(12).reshape(3,4), columns=['A', 'B', 'C', 'D'])
df
# Out:
#    A  B   C   D
# 0  0  1   2   3
# 1  4  5   6   7
# 2  8  9  10  11

# %% [markdown]
# # dataframe 删除列

# %%
# DataFrame.drop(labels=None,axis=0, index=None, columns=None, inplace=False)
# labels 就是要删除的行列的名字，用列表给定
# axis 默认为0，指删除行，因此删除columns时要指定axis=1；
# index 直接指定要删除的行
# columns 直接指定要删除的列
# inplace=False，默认该删除操作不改变原数据，而是返回一个执行删除操作后的新dataframe；
# inplace=True，则会直接在原数据上进行删除操作，删除后无法返回。

# %%
#Drop columns 方法一
df.drop(['B', 'C'], axis=1) # 删除列B和列C
# axis 默认为0，指删除行，因此删除columns时要指定axis=1；
# Out:
#    A   D
# 0  0   3
# 1  4   7
# 2  8  11

# %%
#Drop columns 方法二
df.drop(columns=['B', 'C'])
# Out:
#    A   D
# 0  0   3
# 1  4   7
# 2  8  11

# %% [markdown]
# # Drop rows 删除行

# %%
# Drop rows 删除行 方法一
df.drop([0, 1]) #删除第一行和第二行
# Out:
#    A  B   C   D
# 2  8  9  10  11

# %%
# Drop rows 删除行 方法二
df.drop(index=[0, 1]) #删除第一行和第二行
# Out:
#    A  B   C   D
# 2  8  9  10  11

# %% [markdown]
# # 删除指定的行

# %%
# 删除指定的行 
import pandas as pd
df = {'DataBase':['mysql','test','test','test','test'],'table':['user','student','course','sc','book']}
df = pd.DataFrame(df)
df
# Out:
#   DataBase    table
# 0    mysql     user
# 1     test  student
# 2     test   course
# 3     test       sc
# 4     test     book

# %%
#删除table值为sc的那一行
df.drop(index=(df.loc[(df['table']=='sc')].index))
# Out:
#   DataBase    table
# 0    mysql     user
# 1     test  student
# 2     test   course
# 4     test     book

# %%
df = pd.DataFrame([[1, 2], [3, 4]], columns=list('AB'), index=['x', 'y'])
df
# Out:
#    A  B
# x  1  2
# y  3  4

# %%
df2 = pd.DataFrame([[5, 6], [7, 8]], columns=list('AB'), index=['x', 'y'])
df2
# Out:
#    A  B
# x  5  6
# y  7  8

# %%
df.append(df2) #添加两行
# Out:
#    A  B
# x  1  2
# y  3  4
# x  5  6
# y  7  8

# %%
df.append(df2, ignore_index=True) #忽略index number
# Out:
#    A  B
# 0  1  2
# 1  3  4
# 2  5  6
# 3  7  8

# %%
pd.concat([pd.DataFrame([i], columns=['A']) for i in range(5)], #i 是从0到4
          ignore_index=True)
